# %% [markdown]
# Task02

# %% [markdown]
# Problem Statement- Performing data cleaning and Exploratory Data Analysis on Titanic Dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\SHONIMA SHAJI\\OneDrive\\Desktop\\Shonima IIsem\\Prodigy\\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# DATA CLEANING

# %%
null_counts=df.isnull().sum()

# %%
#constructing bar chart for visual representation for null values found in each columns
null_counts.plot(kind='bar', figsize=(10, 6))  
plt.xlabel('columns')
plt.ylabel('no.of null values')
plt.title('Null values in each column')
plt.xticks(rotation=45)
plt.show()

# %%
null_counts
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
#filling the null valuesby median method for the column age
df['Age'].fillna(df['Age'].median(),inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
#understanding the distribution of values and the common values for the column Embarked.
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
#changing the data types for the columns Survived, PClass, Sex, Age and Embarked.
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('category')
df['Age']=df['Age'].astype('int')
df['Embarked']=df['Embarked'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 49.4+ KB

# %%
sns.countplot(x='Survived', data=df, palette = 'cividis');
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\328205418.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=df, palette = 'cividis');

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\4031118088.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Survived','Sex'])['Survived'].count()
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
#Survival Analysis of males
df[df['Sex'] == 'male'].Survived.groupby(df.Survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("Male survival rate")
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\3462989249.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['Sex'] == 'male'].Survived.groupby(df.Survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')

# %%
#Survival Analysis by females
df[df['Sex'] == 'female'].Survived.groupby(df.Survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')
plt.axis('equal')
plt.legend(["Perished","Survived"])
plt.title("Female survival rate")
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\192915918.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['Sex'] == 'female'].Survived.groupby(df.Survived).count().plot(kind='pie', figsize=(6, 6),explode=[0,0.05],autopct='%1.1f%%')

# %%
#Survival Analysis by PClass
plt.figure(figsize=(8, 6))
sns.countplot(x='Survived', hue='Pclass', data=df , palette = 'summer')
plt.title('Survival Count by PClass')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.legend(title='PClass', loc='upper right')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
plt.show()

# %%
#Age Distribution
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['Age'].dropna(), kde=True, color = 'darkviolet')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
pd.crosstab([df.Sex,df.Survived],df.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_95818_row0_col0, #T_95818_row0_col1, #T_95818_row0_col3, #T_95818_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_95818_row0_col2, #T_95818_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_95818_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_95818_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_95818_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_95818_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_95818_row2_col1, #T_95818_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_95818_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_95818_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_95818_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_95818_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_95818_row4_col0, #T_95818_row4_col1, #T_95818_row4_col2, #T_95818_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_95818">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_95818_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_95818_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_95818_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_95818_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95818_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_95818_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_95818_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_95818_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_95818_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_95818_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_95818_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_95818_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_95818_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_95818_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_95818_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_95818_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_95818_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_95818_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_95818_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_95818_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_95818_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_95818_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_95818_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_95818_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_95818_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_95818_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_95818_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_95818_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_95818_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_95818_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_95818_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_95818_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('Oldest person Survived was of:',df['Age'].max())
print('Youngest person Survived was of:',df['Age'].min())
print('Average person Survived was of:',df['Age'].mean())
# Out:
# Oldest person Survived was of: 80
# Youngest person Survived was of: 0
# Average person Survived was of: 29.34567901234568

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x = 'Embarked', data=df, palette = 'rocket')
plt.title('Embarked Distribution')
plt.xlabel('Port of Embarkation')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\2759768648.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Embarked', data=df, palette = 'rocket')

# %%
#box plot for identifying outliers for the column Age
plt.figure(figsize=(8, 6))
sns.boxplot(x='Age', data=df, palette = 'husl')
plt.xlabel('Age')
plt.title('Box Plot: Distribution of Age')
plt.grid(True)
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\3018151951.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Age', data=df, palette = 'husl')

# %%
#count plot for SibSp column
sns.countplot(x='SibSp', data=df, palette ='mako')
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\3831765866.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='SibSp', data=df, palette ='mako')

# %%
#count plot for Parch column
plt.figure(figsize=(8, 6))
sns.countplot(x='Parch', data=df, palette = 'plasma')
plt.title('Distribution of Parch')
plt.xlabel('Number of Parents/Children Aboard')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\SHONIMA SHAJI\AppData\Local\Temp\ipykernel_1172\1997754131.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Parch', data=df, palette = 'plasma')
